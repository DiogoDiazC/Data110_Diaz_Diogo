# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Anscombe's Quartet:
x = [7,12, 13, 3, 11, 14, 9, 4, 10, 8, 5]
y1 = [8.22, 9.34, 7.12, 6.90, 5.55, 9.74, 9.12, 5.53, 9.94, 11.42, 7.33]
y2 = [4.23, 10.12, 9.33, 7.29, 8.40, 8.55, 11.34, 4.20, 12.67, 6.36, 5.44]
y3 = [5.12, 12.34, 11.89, 4.97, 6.44, 5.54, 9.29, 7.12, 5.35, 10.22, 4.33]
x4 = [8, 5, 7, 5, 5, 8, 6, 10, 6, 10, 8]
y4 = [6.12, 4.55, 7.10, 5.34, 9.25, 6.22, 5.88, 10.52, 7.68, 790, 10.12]

# %%
plt.scatter(x, y1)

# %%
plt.scatter(x, y2)

# %%
plt.scatter(x, y3)

# %%
plt.scatter(x, y4)

# %%
plt.scatter(x4, y4)

# %% [markdown]
# Q1: It differs despite having similar numbers, due to how the y axis changes. This can be the cause of a rise or fall of whatever the chart would be about.
#
# Q2: It implies that x4 and y4 has a much bigger impact, whether positive or negative. This also determines certain outliers within that dataset.
#
# Q3:It's important to visualize the data through a chart to make sure there's no outliers that could hide under someone's eye when they only look into the raw data.
